# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.4-cp39-cp39-macosx_10_9_x86_64.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 704 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from pandas) (2.8.1)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.20.3-cp39-cp39-macosx_10_9_x86_64.whl (16.1 MB)
#      |████████████████████████████████| 16.1 MB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.20.3 pandas-1.2.4
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.0.16/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv('car data.csv')

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
data['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
#checking for null values
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data['Current_Year']=2021

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year
# 0      Dealer       Manual      0          2021
# 1      Dealer       Manual      0          2021
# 2      Dealer       Manual      0          2021
# 3      Dealer       Manual      0          2021
# 4      Dealer       Manual      0          2021

# %%
data['No_of_year']=data['Current_Year']-data['Year']
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current_Year  No_of_year
# 0      Dealer       Manual      0          2021           7
# 1      Dealer       Manual      0          2021           8
# 2      Dealer       Manual      0          2021           4
# 3      Dealer       Manual      0          2021          10
# 4      Dealer       Manual      0          2021           7

# %%
final_data=data.drop(['Car_Name'],axis=1)

# %%
final_data.drop(['Current_Year'],axis=1,inplace=True)

# %%
final_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  No_of_year
# 0       Manual      0           7
# 1       Manual      0           8
# 2       Manual      0           4
# 3       Manual      0          10
# 4       Manual      0           7

# %%
final_data=pd.get_dummies(final_data,drop_first=True) 
# to convert into one hot encoding and drop_first will prevent dummy variable trap

# %%
final_data.shape
# Out:
# (301, 10)

# %%
final_data.corr()
# Out:
#                             Year  Selling_Price  Present_Price  Kms_Driven  \
# Year                    1.000000       0.236141      -0.047584   -0.524342
# Selling_Price           0.236141       1.000000       0.878983    0.029187
# Present_Price          -0.047584       0.878983       1.000000    0.203647
# Kms_Driven             -0.524342       0.029187       0.203647    1.000000
# Owner                  -0.182104      -0.088344       0.008057    0.089216
# No_of_year             -1.000000      -0.236141       0.047584    0.524342
# Fuel_Type_Diesel        0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol       -0.059959      -0.540571      -0.465244   -0.172874
# Seller_Type_Individual -0.039896      -0.550724      -0.512030   -0.101419
# Transmission_Manual     0.000394      -0.367128      -0.348715   -0.162510
#
#                            Owner  No_of_year  Fuel_Type_Diesel  \
# Year                   -0.182104   -1.000000          0.064315
# Selling_Price          -0.088344   -0.236141          0.552339
# Present_Price           0.008057    0.047584          0.473306
# Kms_Driven              0.089216    0.524342          0.172515
# Owner                   1.000000    0.182104         -0.053469
# No_of_year              0.182104    1.000000         -0.064315
# Fuel_Type_Diesel       -0.053469   -0.064315          1.000000
# Fuel_Type_Petrol        0.055687    0.059959         -0.979648
# Seller_Type_Individual  0.124269    0.039896         -0.350467
# Transmission_Manual    -0.050316   -0.000394         -0.098643
#
#                         Fuel_Type_Petrol  Seller_Type_Individual  \
# Year                           -0.059959               -0.039896
# Selling_Price                  -0.540571               -0.550724
# Present_Price                  -0.465244               -0.512030
# Kms_Driven                     -0.172874               -0.101419
# Owner                           0.055687                0.124269
# No_of_year                      0.059959                0.039896
# Fuel_Type_Diesel               -0.979648               -0.350467
# Fuel_Type_Petrol                1.000000                0.358321
# Seller_Type_Individual          0.358321                1.000000
# Transmission_Manual             0.091013                0.063240
#
#                         Transmission_Manual
# Year                               0.000394
# Selling_Price                     -0.367128
# Present_Price                     -0.348715
# Kms_Driven                        -0.162510
# Owner                             -0.050316
# No_of_year                        -0.000394
# Fuel_Type_Diesel                  -0.098643
# Fuel_Type_Petrol                   0.091013
# Seller_Type_Individual             0.063240
# Transmission_Manual                1.000000

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# Requirement already satisfied: pandas>=0.23 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from seaborn) (1.20.3)
# Collecting scipy>=1.0
#   Downloading scipy-1.6.3-cp39-cp39-macosx_10_9_x86_64.whl (30.9 MB)
#      |████████████████████████████████| 30.9 MB 593 kB/s eta 0:00:01
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.4.2-cp39-cp39-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 822 kB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp39-cp39-macosx_10_10_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 504 kB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
# Requirement already satisfied: six in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/Cellar/jupyterlab/3.0.16/libexec/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: pillow, kiwisolver, cycler, scipy, matplotlib, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.2.0 scipy-1.6.3 seaborn-0.11.1
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.0.16/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
